# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Memes820/Flyrank-Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
# Im picking Lane 1: Ranking Signals Analysis. It fits well with what I have already learned running the starter notebooks and its a good foundation before i decide if I want to go deeper into scoring or clustering later

# %%
# Lane chosen: Ranking Signal Analysis

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
# Question: Which observable content and search signals are associated with a page losing visibility?
# Unit of analysis: one content page
# Output: a ranked signal report showing which signals correlate most with decline
# Decision this improves: which pages a content team should review first, given limited reviewer time.
# Cost of a wrong call : flagging a healthy page wastes reviewer time: missing a truly declining page lets it keep losing visibility unnoticed. Since review capacity is limited, both cost matter.

# %%
# Decision supported: which pages to review first for possible decline

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# Two real numbers from the starter pipeline back this lane: search volume barely predicts visibility, yet a learned model beats a simple hand-written rule by a wide margin on Precise@50 (0.740 vs 0.240). That gap shows there is real, minable signla in the data for this lane.

# %%
print("Correlation (search_volume vs impressions_90d): 0.001")
print("Baseline rule Precision@50: 0.240")
print("Random forest Precision@50 0.740")
# Out:
# Correlation (search_volume vs impressions_90d): 0.001
# Baseline rule Precision@50: 0.240
# Random forest Precision@50 0.740

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
# My work can say what is observed, measured and directional. for example which signals tend to move together with visibility, or which pages look higher risk based on patterns in past data. It cannot calim to have found a Google algorithm factor and it cannot clain a refresh will cause recovery, only a controlled experiment could prove that. This is decision support, not proof.

# %%
# No additional computation needed here this section is reflection only.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
